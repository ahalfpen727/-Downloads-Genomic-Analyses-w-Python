# %% [markdown]
# ## Explore Variant Call Files (VCFs)

# %% [markdown]
# ### import standard libraries

# %%
import sys
# sys.path
import sqlite3
import pprint
import collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### import variant-analysis libraries

# %%
import vcfnp
import vcf as vcf
import pybedtools
import allel as al
from comut import comut
from pysam import VariantFile
from vcfparser import VcfParser
# Out:
# Successfully loaded .Rprofile at
#
# Sun Nov 22 21:44:03 2020

# %% [markdown]
# ### Use "Magic Commands" to interact with the sheell and find the data

# %%
# %%bash
# cd /media/drew/easystore/Current-Analysis/AnalysisBaseDir/GSA_Data/2018_07/
# ls -l
# Out:
# total 4874750
# -rwxrwxrwx 1 drew drew        124 Oct 27 03:58 20180117.acmg59.tsv
# -rwxrwxrwx 1 drew drew        124 Oct 26 20:26 2018_07.acmg59.tsv
# -rwxrwxrwx 1 drew drew  516535388 Oct 23 14:03 2018_07.clinvar.GRCh38.bcf
# -rwxrwxrwx 1 drew drew    1366855 Oct 23 14:03 2018_07.clinvar.GRCh38.bcf.csi
# -rwxrwxrwx 1 drew drew  244325278 Nov 22 20:57 2018_07.clinvar.GRCh38.GSA-24v1.interleaved-haplo.vcf
# -rwxrwxrwx 1 drew drew 1717242302 Nov 21 09:30 2018_07.clinvar.GRCh38.GSA-24v1.vcf
# -rwxrwxrwx 1 drew drew  516535720 Oct 20 05:29 2018_07.csq.GRCh38.bcf
# -rwxrwxrwx 1 drew drew       3855 Nov 21 21:39 2018_07.csq.GRCh38.stats
# -rwxrwxrwx 1 drew drew  516535720 Oct 21 02:40 2018_07.GSA-24v1_0.csq.GRCh38.bcf
# -rwxrwxrwx 1 drew drew    1366954 Oct 21 02:41 2018_07.GSA-24v1_0.csq.GRCh38.bcf.csi
# -rwxrwxrwx 1 drew drew  491651240 Oct 18 00:38 2018_07.GSA-24v1_0.GRCh38.bcf
# -rwxrwxrwx 1 drew drew    1362484 Oct 18 00:38 2018_07.GSA-24v1_0.GRCh38.bcf.csi
# ...

# %%
vcf_reader = '/media/drew/easystore/Current-Analysis/AnalysisBaseDir/GSA_Data/2018_07/Mocha_out/2018_07.other.GRCh38.vcf'
vcfcalls = al.read_vcf(vcf_reader)
sorted(vcfcalls.keys())
# Out:
# ['calldata/GT',
#  'samples',
#  'variants/ALT',
#  'variants/CHROM',
#  'variants/FILTER_PASS',
#  'variants/ID',
#  'variants/POS',
#  'variants/QUAL',
#  'variants/REF']

# %%
df = al.vcf_to_dataframe(vcf_reader)
df
# Out:
#      CHROM      POS               ID REF ALT_1  ALT_2  ALT_3  QUAL  \
# 0     chrY  2787139       rs11575897   G     A    NaN    NaN   NaN
# 1     chrY  2789135        rs2534636   C     T    NaN    NaN   NaN
# 2     chrY  2793265       rs35840667   T     G    NaN    NaN   NaN
# 3     chrY  2793653        rs2253109   A     G    NaN    NaN   NaN
# 4     chrY  2795644       rs35067692   T     G    NaN    NaN   NaN
# 5     chrY  2800415        rs2058276   T     C    NaN    NaN   NaN
# 6     chrY  2811059       rs13303871   A     G    NaN    NaN   NaN
# 7     chrY  2834997       rs28813670   G     T    NaN    NaN   NaN
# 8     chrY  2837813       rs11799203   G     A    NaN    NaN   NaN
# 9     chrY  2841514   2010-08-Y-3172   A     C    NaN    NaN   NaN
# 10    chrY  2842268       rs34402762   T     G    NaN    NaN   NaN
# 11    chrY  2854465        rs2075640   A     G    NaN    NaN   NaN
# 12    chrY  2854773         GA026677   T     C    NaN    NaN   NaN
# ...

# %%
vcfgsa = '/media/drew/easystore/Current-Analysis/AnalysisBaseDir/GSA_Data/2018_07/Mocha_out/2018_07.other.GRCh38.vcf'
with open(vcfgsa, mode='r') as f:
    print(f.read())
# Out:
# ##fileformat=VCFv4.2
# ##FILTER=<ID=PASS,Description="All filters passed">
# ##contig=<ID=chr1,length=248956422>
# ##contig=<ID=chr2,length=242193529>
# ##contig=<ID=chr3,length=198295559>
# ##contig=<ID=chr4,length=190214555>
# ##contig=<ID=chr5,length=181538259>
# ##contig=<ID=chr6,length=170805979>
# ##contig=<ID=chr7,length=159345973>
# ##contig=<ID=chr8,length=145138636>
# ##contig=<ID=chr9,length=138394717>
# ##contig=<ID=chr10,length=133797422>
# ##contig=<ID=chr11,length=135086622>
# ##contig=<ID=chr12,length=133275309>
# ##contig=<ID=chr13,length=114364328>
# ##contig=<ID=chr14,length=107043718>
# ##contig=<ID=chr15,length=101991189>
# ##contig=<ID=chr16,length=90338345>
# ##contig=<ID=chr17,length=83257441>
# ##contig=<ID=chr18,length=80373285>
# ##contig=<ID=chr19,length=58617616>
# ##contig=<ID=chr20,length=64444167>
# ##contig=<ID=chr21,length=46709983>
# ##contig=<ID=chr22,length=50818468>
# ##contig=<ID=chrX,length=156040895>
# ##contig=<ID=chrY,length=57227415>
# ...

# %%
vcfgsa = '/media/drew/easystore/Current-Analysis/AnalysisBaseDir/GSA_Data/2018_07/Mocha_out/2018_07.unphased.GRCh38.vcf'
with open(vcfgsa, mode='r') as f:
    print(f.read())
# Out:
# ##fileformat=VCFv4.2
# ##FILTER=<ID=PASS,Description="All filters passed">
# ##BPM=GSA-24v1-0_A2.bpm
# ##CSV=GSA-24v1-0_A2.csv
# ##EGT=GSA-24v1-0_A1_ClusterFile.egt
# ##BeadSet_Order=1382,1379,1381,1366,1346,1348,1372,1371,1370,1398,1363,1394,1356,1374,1401,1369,1368,1358,1359,1397,1387,1364,1402,1392,1390,1367,1357,1365,1355,1391,1386,1361
# ##bcftools_viewVersion=1.10.2+htslib-1.10.2-110-gda59588
# ##bcftools_viewCommand=view --header-only 2018_07.GSA-24v1_0.vcf; Date=Mon Oct 26 16:10:49 2020
# ##INFO=<ID=ALLELE_A,Number=1,Type=Integer,Description="A allele">
# ##INFO=<ID=ALLELE_B,Number=1,Type=Integer,Description="B allele">
# ##INFO=<ID=GC,Number=1,Type=Float,Description="GC ratio content around the variant">
# ##FORMAT=<ID=GT,Number=1,Type=String,Description="Genotype">
# ##FORMAT=<ID=BAF,Number=1,Type=Float,Description="B Allele Frequency">
# ##FORMAT=<ID=LRR,Number=1,Type=Float,Description="Log R Ratio">
# ##contig=<ID=chrchr1,length=248956422>
# ...
